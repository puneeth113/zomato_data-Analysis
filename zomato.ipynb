# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#accesing data or exracting data 

df = pd.read_csv(r"C:\Users\punee\Downloads\archive (45).zip")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# ...

# %%
#removing a unwanted columns 

df.drop_duplicates(inplace=True)

# %%
df.head()
df=df.drop("Unnamed: 0.1" , axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0     restaurant name restaurant type  rate (out of 5)  \
# 0           0        #FeelTheROLL     Quick Bites              3.4
# 1           1          #L-81 Cafe     Quick Bites              3.9
# 2           2             #refuel            Cafe              3.7
# 3           3  '@ Biryani Central   Casual Dining              2.7
# 4           4          '@ The Bbq   Casual Dining              2.8
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
# 3             135                  550.0          Yes            No
# 4              40                  700.0          Yes            No
#
#                                        cuisines type  \
# 0                                          Fast Food
# ...

# %%
#checking any null values 

df.isnull().sum()
# Out:
# Unnamed: 0                0
# restaurant name           0
# restaurant type           0
# rate (out of 5)          68
# num of ratings            0
# avg cost (two people)    57
# online_order              0
# table booking             0
# cuisines type             0
# area                      0
# local address             0
# dtype: int64

# %%
#dropimg null values 

df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# restaurant name          0
# restaurant type          0
# rate (out of 5)          0
# num of ratings           0
# avg cost (two people)    0
# online_order             0
# table booking            0
# cuisines type            0
# area                     0
# local address            0
# dtype: int64

# %%
#basic calculations discribing data df 


df.describe()
# Out:
#         Unnamed: 0  rate (out of 5)  num of ratings  avg cost (two people)
# count  6984.000000      6984.000000     6984.000000            6984.000000
# mean   3553.300401         3.514304      190.928837             542.544244
# std    2049.582971         0.463489      596.717894             464.266828
# min       0.000000         1.800000        1.000000              40.000000
# 25%    1781.750000         3.200000       15.000000             300.000000
# 50%    3556.500000         3.500000       40.000000             400.000000
# 75%    5326.250000         3.800000      130.000000             600.000000
# max    7104.000000         4.900000    16345.000000            6000.000000

# %%
#checking what are the columns in data frame 

df.columns
# Out:
# Index(['Unnamed: 0', 'restaurant name', 'restaurant type', 'rate (out of 5)',
#        'num of ratings', 'avg cost (two people)', 'online_order',
#        'table booking', 'cuisines type', 'area', 'local address'],
#       dtype='object')

# %% [markdown]
# # General analysis

# %% [markdown]
# # 1 . How many restaurants are listed on Zomato?

# %%
df['restaurant name'].count()
# Out:
# 6984

# %% [markdown]
# # there are 6984 hotels or restrounts are listed in zomato

# %% [markdown]
#  # 2 . What are the different cuisines available?

# %%
cusines=  df["cuisines type"].unique()
cusinesdf=pd.DataFrame(cusines)
cusinesdf.columns=["cuisine type"]
print(cusinesdf['cuisine type'].unique())
# Out:
# ['Fast Food' 'Fast Food, Beverages' 'Cafe, Beverages' ...
#  'Italian, Mexican, Mediterranean, North Indian, Continental'
#  'Cafe, Italian, Continental, Burger'
#  'Turkish, Fast Food, Biryani, Chinese']

# %% [markdown]
# # above are list of cuisine in zomato data set

# %% [markdown]
#  # 3 . Which cuisine is the most popular?

# %%
df.head()
# Out:
#    Unnamed: 0     restaurant name restaurant type  rate (out of 5)  \
# 0           0        #FeelTheROLL     Quick Bites              3.4
# 1           1          #L-81 Cafe     Quick Bites              3.9
# 2           2             #refuel            Cafe              3.7
# 3           3  '@ Biryani Central   Casual Dining              2.7
# 4           4          '@ The Bbq   Casual Dining              2.8
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
# 3             135                  550.0          Yes            No
# 4              40                  700.0          Yes            No
#
#                                        cuisines type  \
# 0                                          Fast Food
# ...

# %%
cuisine_rating =df.groupby("cuisines type")["num of ratings"].count().reset_index().sort_values(by="num of ratings" , ascending=False).head(5)

# %%
cuisine_rating
# Out:
#                             cuisines type  num of ratings
# 1501                North Indian, Chinese             417
# 1440                         North Indian             413
# 1959                         South Indian             342
# 1000                            Fast Food             132
# 2031  South Indian, North Indian, Chinese             127

# %%
#drowing barplot

values = cuisine_rating['num of ratings']
barplot = plt.bar(x=cuisine_rating['cuisines type'] , height=cuisine_rating['num of ratings'])

plt.bar_label(barplot , values)
plt.xticks(rotation=5)
plt.figure(figsize=(10,6))

# %% [markdown]
# # most popular cuisine is NORTH INDIAN ,CHINESE with 417 ratings followed by north indian cuisine 413

# %%
plt.savefig('bar_graph.png')

# %% [markdown]
# # 4 . What is the average rating of restaurants?

# %%
avg_rating  = df['rate (out of 5)'].mean()
print("the average ratings of every restrount is " , avg_rating)
# Out:
# the average ratings of every restrount is  3.5143041237113404

# %% [markdown]
# # the averahe ratings is 3.51

# %%
df.head(3)
# Out:
#    Unnamed: 0 restaurant name restaurant type  rate (out of 5)  \
# 0           0    #FeelTheROLL     Quick Bites              3.4
# 1           1      #L-81 Cafe     Quick Bites              3.9
# 2           2         #refuel            Cafe              3.7
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
#
#           cuisines type                            area      local address
# 0             Fast Food                       Bellandur          Bellandur
# 1  Fast Food, Beverages  Byresandra,Tavarekere,Madiwala                HSR
# 2       Cafe, Beverages               Bannerghatta Road  Bannerghatta Road

# %%
#ploting data based on ratings of users 

rating_df =df.groupby("restaurant type")["rate (out of 5)"].mean().reset_index().sort_values(by="rate (out of 5)" , ascending=False).head(5)

# %%
rating_df
# Out:
#         restaurant type  rate (out of 5)
# 8              Bar, Pub           4.6000
# 63    Microbrewery, Pub           4.4625
# 19         Cafe, Lounge           4.4000
# 60    Microbrewery, Bar           4.4000
# 44  Fine Dining, Lounge           4.4000

# %%
barplot =sns.barplot(data=rating_df , y="restaurant type" , x="rate (out of 5)")
plt.savefig("snsbarploat.png")

# %% [markdown]
# # moste rated restrounte type is Bar and pub with 4.6 followed by 4.4  Microbrewery, Pub

# %% [markdown]
# # 4. how may hotel which accept the online order

# %%
df.head(3)
# Out:
#    Unnamed: 0 restaurant name restaurant type  rate (out of 5)  \
# 0           0    #FeelTheROLL     Quick Bites              3.4
# 1           1      #L-81 Cafe     Quick Bites              3.9
# 2           2         #refuel            Cafe              3.7
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
#
#           cuisines type                            area      local address
# 0             Fast Food                       Bellandur          Bellandur
# 1  Fast Food, Beverages  Byresandra,Tavarekere,Madiwala                HSR
# 2       Cafe, Beverages               Bannerghatta Road  Bannerghatta Road

# %%
online_order_hotel = df.query("`online_order`=='Yes'")
offline_order_hotel = df.query("`online_order`=='No'")

# %%
#ploting the online order taking hotels 
online_order_hotel['online_order'].count()
# Out:
# 3721

# %% [markdown]
# # the hotel which accept online order are 3721

# %%
offline_order_hotel["online_order"].count()
# Out:
# 3263

# %% [markdown]
# # the hotels which accept offline orders are 3263

# %%
df.head()
# Out:
#    Unnamed: 0     restaurant name restaurant type  rate (out of 5)  \
# 0           0        #FeelTheROLL     Quick Bites              3.4
# 1           1          #L-81 Cafe     Quick Bites              3.9
# 2           2             #refuel            Cafe              3.7
# 3           3  '@ Biryani Central   Casual Dining              2.7
# 4           4          '@ The Bbq   Casual Dining              2.8
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
# 3             135                  550.0          Yes            No
# 4              40                  700.0          Yes            No
#
#                                        cuisines type  \
# 0                                          Fast Food
# ...

# %%
orderDf=df.groupby(["online_order"])["restaurant name"].count().reset_index().sort_values(by="restaurant name" , ascending=False)

# %%
#renaming the column 

orderDf.rename(columns={"restaurant name":"count"} , inplace=True)
orderDf
# Out:
#   online_order  count
# 1          Yes   3721
# 0           No   3263

# %%
#setting count values 
count = orderDf["count"]


barplt =plt.bar(x=orderDf["online_order"] , height=orderDf["count"] , width=0.6)
plt.bar_label(barplt , count)
plt.xlabel("online order acceptance ")
plt.ylabel("count")
plt.show()

# %% [markdown]
# # their are 3721 hotels which accept online orders and 3263 hotels which accept which did not accept

# %% [markdown]
# # insights -------- 1

# %% [markdown]
# 1    . there are 6984 hotels or restrounts are listed in zomato
#
# 2  . Fast Food' 'Fast Food, Beverages' 'Cafe, Beverages' ...
#      'Italian, Mexican, Mediterranean  . are popular cuisines
#
# 3 .  popular cuisine is NORTH INDIAN ,CHINESE with 417 ratings followed by north indian cuisine 413
#
# 4   . moste rated restrounte type is Bar and pub with 4.6 followed by 4.4 Microbrewery, Pub
#
# 5  . their are 3721 hotels which accept online orders and 3263 hotels which accept which did not accept

# %% [markdown]
# # 2 Based on location  data ananlysis

# %%
df.head()
# Out:
#    Unnamed: 0     restaurant name restaurant type  rate (out of 5)  \
# 0           0        #FeelTheROLL     Quick Bites              3.4
# 1           1          #L-81 Cafe     Quick Bites              3.9
# 2           2             #refuel            Cafe              3.7
# 3           3  '@ Biryani Central   Casual Dining              2.7
# 4           4          '@ The Bbq   Casual Dining              2.8
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
# 3             135                  550.0          Yes            No
# 4              40                  700.0          Yes            No
#
#                                        cuisines type  \
# 0                                          Fast Food
# ...

# %%
location_based =df.groupby(["local address"])["restaurant type"].count().reset_index().sort_values(by="restaurant type" , ascending=False).head()

# %%
location_based

#renaming restriunt type into a count

location_based.rename(columns={"restaurant type" : "count"} , inplace=True)
location_based
# Out:
#       local address  count
# 86       Whitefield    457
# 0               BTM    442
# 18  Electronic City    403
# 54     Marathahalli    378
# 21              HSR    372

# %%
#ploting 
counter = location_based['count']

location_based.plot(kind="bar" , x='local address' , y="count")

counter
# Out:
# 86    457
# 0     442
# 18    403
# 54    378
# 21    372
# Name: count, dtype: int64

# %% [markdown]
# # whitefield has most number of hotels with 457 followed by BTM 442

# %%
# min hotels based on locations 

location_based_min=df.groupby(["local address"])["restaurant type"].count().reset_index().sort_values(by="restaurant type" , ascending=True).head()

# %%
location_based_min
# Out:
#      local address  restaurant type
# 62          Peenya                1
# 56      Nagarbhavi                1
# 48   Langford Town                1
# 37         Kengeri                1
# 85  West Bangalore                2

# %%
#renaming restriunt type into count 


location_based_min.rename(columns={"restaurant type" : "count"} , inplace=True)
location_based_min
# Out:
#      local address  count
# 62          Peenya      1
# 56      Nagarbhavi      1
# 48   Langford Town      1
# 37         Kengeri      1
# 85  West Bangalore      2

# %%
location_based_min.plot(kind="bar" , x='local address' , y="count")
# Out:
# <Axes: xlabel='local address'>

# %% [markdown]
# # Peenya , NagarBhavi , Langford Town , kengeri have 1 hotels respectively followed by west benglore with 2 hotels

# %% [markdown]
# # 2 . What are the top 5 cities with the highest average restaurant ratings?

# %%
high_ratings =df.groupby("local address")["rate (out of 5)"].mean().reset_index().sort_values(by="rate (out of 5)" , ascending=False).head(5)

# %%
high_ratings
# Out:
#             local address  rate (out of 5)
# 49           Lavelle Road         4.059459
# 72            Sankey Road         4.045455
# 78         St. Marks Road         3.990476
# 41  Koramangala 3rd Block         3.971429
# 48          Langford Town         3.900000

# %%
# plot the data 
ratings = high_ratings['rate (out of 5)']
high_ratings.plot.bar(x='local address' , y='rate (out of 5)')
ratings
# Out:
# 49    4.059459
# 72    4.045455
# 78    3.990476
# 41    3.971429
# 48    3.900000
# Name: rate (out of 5), dtype: float64

# %% [markdown]
# # Lavelle Road have most has highest average restrount rating  4.05 with Sankey Road 4.04 and

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# ...

# %% [markdown]
# # 3. Which city has the most variety in cuisines?

# %%
df.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0 restaurant name restaurant type  rate (out of 5)  \
# 0             0           0    #FeelTheROLL     Quick Bites              3.4
# 1             1           1      #L-81 Cafe     Quick Bites              3.9
# 2             2           2         #refuel            Cafe              3.7
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
#
#           cuisines type                            area      local address
# 0             Fast Food                       Bellandur          Bellandur
# 1  Fast Food, Beverages  Byresandra,Tavarekere,Madiwala                HSR
# 2       Cafe, Beverages               Bannerghatta Road  Bannerghatta Road

# %%
most_variety_cuisine=df.groupby(["local address"])["cuisines type"].count().reset_index().sort_values(by="cuisines type" , ascending=False).head(5)

# %%
most_variety_cuisine['cuisines type'] = most_variety_cuisine["cuisines type"].unique()
# Out:
# array([459, 458, 404, 381, 378], dtype=int64)

# %%
most_variety_cuisine
# Out:
#       local address  cuisines type
# 86       Whitefield            459
# 0               BTM            458
# 18  Electronic City            404
# 54     Marathahalli            381
# 21              HSR            378

# %%
#renaming the cuisine type into count 


most_variety_cuisine.rename(columns={"cuisines type" : "count"} , inplace=True)
most_variety_cuisine
# Out:
#       local address  count
# 86       Whitefield    459
# 0               BTM    458
# 18  Electronic City    404
# 54     Marathahalli    381
# 21              HSR    378

# %%
#ploting the data 


most_variety_cuisine.plot(kind="bar" , x="local address" , y="count")
most_variety_cuisine['count']
# Out:
# 86    459
# 0     458
# 18    404
# 54    381
# 21    378
# Name: count, dtype: int64

# %%
#line plot
most_variety_cuisine.plot(kind='line' , x="local address" , y="count"  , marker="*")
# Out:
# <Axes: xlabel='local address'>

# %% [markdown]
# # whitefeild has most number of vierity of cuisine followed by BTM

# %%
df.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0 restaurant name restaurant type  rate (out of 5)  \
# 0             0           0    #FeelTheROLL     Quick Bites              3.4
# 1             1           1      #L-81 Cafe     Quick Bites              3.9
# 2             2           2         #refuel            Cafe              3.7
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
#
#           cuisines type                            area      local address
# 0             Fast Food                       Bellandur          Bellandur
# 1  Fast Food, Beverages  Byresandra,Tavarekere,Madiwala                HSR
# 2       Cafe, Beverages               Bannerghatta Road  Bannerghatta Road

# %% [markdown]
#  # 4. Which areas within a city have the most restaurants?

# %%
most_number_res=df.groupby(["local address"])["restaurant name"].count().reset_index().sort_values(by="restaurant name" , ascending=False).head(5)

# %%
most_number_res
# Out:
#       local address  restaurant name
# 86       Whitefield              459
# 0               BTM              458
# 18  Electronic City              404
# 54     Marathahalli              381
# 21              HSR              378

# %%
# changinh restrount name into count

most_number_res.rename(columns={"restaurant name" : "count"} , inplace=True)

# %%
sns.barplot(data=most_number_res , x='local address'  , y="count")
most_number_res['count']

value=most_number_res['count']

for index, value in enumerate(most_number_res['count']):
    plt.text(index, value + 1, str(value), ha='center')

# %% [markdown]
# # whitefeild has most number of restrount  (459) followed by BTM (458) and Electronic city (404)

# %% [markdown]
# # 5. What is the average cost for two people in different cities?

# %%
high_average_cost =df.groupby(["local address"])["avg cost (two people)"].mean().reset_index().sort_values(by="avg cost (two people)" , ascending=False).head(5)

# %%
high_average_cost['avg cost (two people)'] =np.round(high_average_cost['avg cost (two people)'] , 3)

# %%
high_average_cost
# Out:
#        local address  avg cost (two people)
# 72       Sankey Road               2886.364
# 49      Lavelle Road               1548.649
# 64  Race Course Road               1373.214
# 50           MG Road               1340.476
# 67    Residency Road               1205.769

# %%
#ploting data 


sns.barplot(data = high_average_cost , y="local address" , x="avg cost (two people)")
high_average_cost['avg cost (two people)']
# Out:
# 72    2886.364
# 49    1548.649
# 64    1373.214
# 50    1340.476
# 67    1205.769
# Name: avg cost (two people), dtype: float64

# %% [markdown]
# # Sankey Road  has highest average cost of people about 2886 followed by Lavelle Road 1548 and Race Course Road 1373

# %%
low_average_cost =df.groupby(["local address"])["avg cost (two people)"].mean().reset_index().sort_values(by="avg cost (two people)" , ascending=True).head(5)

# %%
low_average_cost
# Out:
#       local address  avg cost (two people)
# 56       Nagarbhavi             250.000000
# 59  North Bangalore             291.666667
# 62           Peenya             300.000000
# 12      City Market             318.368421
# 88        Yelahanka             325.000000

# %%
#ploting data 


low_average_cost.plot(kind="bar" , x="local address" , y="avg cost (two people)")

low_average_cost['avg cost (two people)'] =np.round(low_average_cost["avg cost (two people)"] , 3)

value=low_average_cost['avg cost (two people)']

for index, value in enumerate(low_average_cost['avg cost (two people)']):
    plt.text(index, value + 1, str(value), ha='center')
plt.xlabel("Name of street ")
plt.ylabel("cost avg")
# Out:
# Text(0, 0.5, 'cost avg')

# %% [markdown]
# # Nagar Bhavi has low average cost for two people followed by North BEnglore and Peenya

# %%
#average cost comaprission

sns.distplot(x=df['avg cost (two people)'])
# Out:
# C:\Users\punee\AppData\Local\Temp\ipykernel_26616\2194780072.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['avg cost (two people)'])
# C:\Users\punee\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %% [markdown]
# # their more number of restrounts whose average cost for 2 two pople is in between 250 to 1000

# %% [markdown]
# # insights -------- 2

# %% [raw]
#  1. whitefield has most number of hotels with 457 followed by BTM 442
#
#  2. Peenya , NagarBhavi , Langford Town , kengeri have 1 hotels respectively followed by west benglore with 2 hotels
#
#  3. Lavelle Road have most has highest average restrount rating  4.05 with Sankey Road 4.04 and
#
#  4. whitefeild has most number of vierity of cuisine followed by BTM
#
#  5. whitefeild has most number of restrount  (459) followed by BTM (458) and Electronic city (404)
#
#  6. Sankey Road  has highest average cost of people about 2886 followed by Lavelle Road 1548 and Race Course Road 1373
#
#  7. Nagar Bhavi has low average(250) cost for two people followed by North BEnglore and Peenya
#
#  8.their more number of restrounts whose average cost for 2 two pople is in between 250 to 1000

# %% [markdown]
#  # 3. Cost Analysis

# %% [markdown]
# # 1. How many restaurants offer online delivery?

# %%
df.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0 restaurant name restaurant type  rate (out of 5)  \
# 0             0           0    #FeelTheROLL     Quick Bites              3.4
# 1             1           1      #L-81 Cafe     Quick Bites              3.9
# 2             2           2         #refuel            Cafe              3.7
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
#
#           cuisines type                            area      local address
# 0             Fast Food                       Bellandur          Bellandur
# 1  Fast Food, Beverages  Byresandra,Tavarekere,Madiwala                HSR
# 2       Cafe, Beverages               Bannerghatta Road  Bannerghatta Road

# %%
order_placement =df.groupby(["online_order"])["restaurant type"].count().reset_index()

# %%
# changing the restrount type int count 

order_placement.rename( columns={"restaurant type" :"count"} , inplace=True)
order_placement
# Out:
#   online_order  count
# 0           No   3378
# 1          Yes   3727

# %%
#ploting data 

sns.barplot(data=order_placement , x="online_order" , y="count")

order_placement['count']
# Out:
# 0    3378
# 1    3727
# Name: count, dtype: int64

# %% [markdown]
# # there are 3378 restrount that  do not accept online order placement and 3727 restrount which accept online order

# %% [markdown]
#  # 2 . What percentage of restaurants offer table booking?

# %%
total_restrount = df['restaurant name'].count()
total_restrount
# Out:
# 7105

# %%
tabel_booking = df [df['table booking']=="Yes"].count()

tabel_booking_provided = tabel_booking['restaurant name']
tabel_booking_provided
# Out:
# 744

# %%
percentage_tabel_booking =np.round((tabel_booking_provided / total_restrount)*100 , 3)
percentage_tabel_booking
# Out:
# 10.471

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# ...

# %%
#represent in pie chart 

tabel_booking =df.groupby(["table booking"])["restaurant type"].count().reset_index()

# %%
# renmae of restrount type intp a count 

tabel_booking.rename(columns={"restaurant type" : "count"} , inplace=True)
tabel_booking
# Out:
#   table booking  count
# 0            No   6361
# 1           Yes    744

# %%
total_tabel_booking =df['table booking'].count()
total_tabel_booking
# Out:
# 7105

# %%
NoPer =np.round( (tabel_booking['count'][0] / total_tabel_booking)*100 , 3)
NoPer

YesPer = np.round( (tabel_booking['count'][1] / total_tabel_booking)*100 , 3)
YesPer
# Out:
# 10.471

# %%
#inserting percentage 

new_data = {'Percentage': [NoPer, YesPer]}

percentage= pd.DataFrame(new_data)

tabel_booking["Percentage"] = percentage
tabel_booking
# Out:
#   table booking  count  Percentage
# 0            No   6361      89.529
# 1           Yes    744      10.471

# %%
#ploting a barplot

tabel_booking.plot.bar(x='table booking' , y="Percentage")


for index, value in enumerate(tabel_booking['Percentage']):
    plt.text(index, value + 1, str(value), ha='center')
tabel_booking['Percentage']
# Out:
# 0    89.529
# 1    10.471
# Name: Percentage, dtype: float64

# %% [markdown]
# # there are 89.529 restrount which does not offer tabel booking service and only 10.471 percentage of restrount offer tabel booking servivce

# %% [markdown]
# # 4 . How do the number of reviews vary across different cities?

# %%
df.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0 restaurant name restaurant type  rate (out of 5)  \
# 0             0           0    #FeelTheROLL     Quick Bites              3.4
# 1             1           1      #L-81 Cafe     Quick Bites              3.9
# 2             2           2         #refuel            Cafe              3.7
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
#
#           cuisines type                            area      local address
# 0             Fast Food                       Bellandur          Bellandur
# 1  Fast Food, Beverages  Byresandra,Tavarekere,Madiwala                HSR
# 2       Cafe, Beverages               Bannerghatta Road  Bannerghatta Road

# %%
reviews_cities=df.groupby(["local address"])["rate (out of 5)"].mean().reset_index().sort_values(by="rate (out of 5)" , ascending=False).head(10)

# %%
#renamaming 

reviews_cities.rename(columns={"rate (out of 5)" : "AvgRating"} , inplace=True)

reviews_cities['AvgRating'] =np.round(reviews_cities['AvgRating'] , 3)

# %%
#ploting data 

reviews_cities.plot(kind="line" , x="local address" , y="AvgRating" , marker="o")
# Out:
# <Axes: xlabel='local address'>

# %%
#barplot

sns.barplot(data=reviews_cities , y="local address" , x="AvgRating")
# Out:
# <Axes: xlabel='AvgRating', ylabel='local address'>

# %% [markdown]
# # Lavelle road street has highest rated with 4.063 followed by Sankey Road with 4.045

# %%
lowest_rated_street=df.groupby(["local address"])["rate (out of 5)"].mean().reset_index().sort_values(by="rate (out of 5)" , ascending=True).head(10)

# %%
lowest_rated_street
# Out:
#                     local address  rate (out of 5)
# 82  Varthur Main Road, Whitefield         2.983333
# 59                North Bangalore         3.050000
# 85                 West Bangalore         3.150000
# 62                         Peenya         3.200000
# 7                    Bommanahalli         3.217391
# 87                  Wilson Garden         3.287097
# 25     ITPL Main Road, Whitefield         3.338462
# 61                Old Madras Road         3.342857
# 79                   Thippasandra         3.346667
# 22                         Hebbal         3.350000

# %%
#renaming the average 

lowest_rated_street.rename(columns={"rate (out of 5)" : "AvgRating"} , inplace=True)
lowest_rated_street
# Out:
#                     local address  AvgRating
# 82  Varthur Main Road, Whitefield   2.983333
# 59                North Bangalore   3.050000
# 85                 West Bangalore   3.150000
# 62                         Peenya   3.200000
# 7                    Bommanahalli   3.217391
# 87                  Wilson Garden   3.287097
# 25     ITPL Main Road, Whitefield   3.338462
# 61                Old Madras Road   3.342857
# 79                   Thippasandra   3.346667
# 22                         Hebbal   3.350000

# %%
#ploting the data 
sns.barplot(data= lowest_rated_street , x='AvgRating' , y="local address")
# Out:
# <Axes: xlabel='AvgRating', ylabel='local address'>

# %% [markdown]
# # Vartur main road whitefield has lowested rated street with 2.98 followed by north benglore and south benglore with 3.05 and 3.15

# %%
#sactter plot based the average ratings

sns.jointplot(x=df['rate (out of 5)'] , y=df['num of ratings'])
# Out:
# C:\Users\punee\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\punee\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # there are more rating  in between 4.0 to 4.8 with less people

# %% [markdown]
# # insights ---- 3

# %% [raw]
# 1 . there are 89.529 restrount which does not offer tabel booking service and only 10.471 percentage of
#       restrount offer tabel booking servivce
#
#
# 2 . Lavelle road street has highest rated with 4.063 followed by Sankey Road with 4.045
#
#
# 3. Vartur main road whitefield has lowested rated street with 2.98 followed by north
#    benglore and south benglore with 3.05 and    3.15¶

# %% [markdown]
# # 4. cost Analysis

# %% [markdown]
# # What is the average cost for two people across different cuisines?

# %%
df.head(2)
# Out:
#    Unnamed: 0.1  Unnamed: 0 restaurant name restaurant type  rate (out of 5)  \
# 0             0           0    #FeelTheROLL     Quick Bites              3.4
# 1             1           1      #L-81 Cafe     Quick Bites              3.9
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
#
#           cuisines type                            area local address
# 0             Fast Food                       Bellandur     Bellandur
# 1  Fast Food, Beverages  Byresandra,Tavarekere,Madiwala           HSR

# %%
high_avgCost=df.groupby(["local address"])["avg cost (two people)"].mean().reset_index().sort_values(by="avg cost (two people)" , ascending=False).head(10)

# %%
#renaming the column 

high_avgCost.rename(columns={"avg cost (two people)" : "Total_avgCost"} , inplace=True)
high_avgCost['Total_avgCost'] = np.round(high_avgCost['Total_avgCost'] , 2)

# %%
high_avgCost
# Out:
#        local address  Total_avgCost
# 72       Sankey Road        2886.36
# 49      Lavelle Road        1548.65
# 64  Race Course Road        1373.21
# 50           MG Road        1340.48
# 67    Residency Road        1205.77
# 27     Infantry Road        1086.36
# 48     Langford Town        1000.00
# 68     Richmond Road         957.50
# 74     Seshadripuram         905.13
# 78    St. Marks Road         897.62

# %%
sns.distplot(df['avg cost (two people)'])
# Out:
# C:\Users\punee\AppData\Local\Temp\ipykernel_26616\167014888.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['avg cost (two people)'])
# C:\Users\punee\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='avg cost (two people)', ylabel='Density'>

# %% [markdown]
# # By overall data there is high density between 0 to 1000

# %%
sns.distplot(high_avgCost['Total_avgCost'])
# Out:
# C:\Users\punee\AppData\Local\Temp\ipykernel_26616\1155568040.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(high_avgCost['Total_avgCost'])
# C:\Users\punee\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Total_avgCost', ylabel='Density'>

# %% [markdown]
# # the average cost is heavly densced in 1000

# %%
#ploating barploat

high_avgCost.plot.bar(x="local address" , y="Total_avgCost")
# Out:
# <Axes: xlabel='local address'>

# %% [markdown]
# # Sankey Road is high average cost for two people with 2886.36 followed by Lavelle Road and Race Course Road with 1548 and 1373 respectively

# %%
#least 

low_avgCost=df.groupby(["local address"])["avg cost (two people)"].mean().reset_index().sort_values(by="avg cost (two people)" , ascending=True).head(10)

# %%
low_avgCost['avg cost (two people)'] = np.round(low_avgCost['avg cost (two people)'] , 2)

# %%
low_avgCost['avg cost (two people)'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# # the average cost for two peole is 230 in lowest average cost restrount

# %%
#ploating data 
sns.distplot(x=low_avgCost['avg cost (two people)'])
# Out:
# C:\Users\punee\AppData\Local\Temp\ipykernel_26616\4291581931.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=low_avgCost['avg cost (two people)'])
# C:\Users\punee\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %% [markdown]
# # there is density starts from 250 and highly densed in 350  in low average cost city streets

# %%
low_avgCost
# Out:
#       local address  avg cost (two people)
# 56       Nagarbhavi                 250.00
# 59  North Bangalore                 291.67
# 62           Peenya                 300.00
# 12      City Market                 318.37
# 88        Yelahanka                 325.00
# 71     Sanjay Nagar                 333.33
# 4      Basavanagudi                 333.52
# 17          Ejipura                 336.25
# 10   CV Raman Nagar                 346.00
# 85   West Bangalore                 350.00

# %%
#ploting a bar graph

low_avgCost.plot.bar(x="local address" , y="avg cost (two people)")
# Out:
# <Axes: xlabel='local address'>

# %% [markdown]
# # Data shows that Nagarbavi has overall less average cost for two people of 250 followed by North Benglore and Peenya with 291 and 300 respectfully

# %% [markdown]
# # 2. Which cuisine is the most expensive?

# %%
df.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0 restaurant name restaurant type  rate (out of 5)  \
# 0             0           0    #FeelTheROLL     Quick Bites              3.4
# 1             1           1      #L-81 Cafe     Quick Bites              3.9
# 2             2           2         #refuel            Cafe              3.7
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
#
#           cuisines type                            area      local address
# 0             Fast Food                       Bellandur          Bellandur
# 1  Fast Food, Beverages  Byresandra,Tavarekere,Madiwala                HSR
# 2       Cafe, Beverages               Bannerghatta Road  Bannerghatta Road

# %%
expensive_cusinine = df.groupby(["cuisines type"])["avg cost (two people)"].sum().reset_index().sort_values(by="avg cost (two people)" , ascending=False).head(10)

# %%
expensive_cusinine.rename(columns={'avg cost (two people)' : "total_avgCost"} , inplace=True)

# %%
#ploating datas


sns.kdeplot(x=expensive_cusinine['total_avgCost'])
# Out:
# C:\Users\punee\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_avgCost', ylabel='Density'>

# %% [markdown]
# # data is highly dense between 50000 and 100000

# %%
#bar graph

sns.barplot(data=expensive_cusinine , y="cuisines type" , x="total_avgCost")
# Out:
# <Axes: xlabel='total_avgCost', ylabel='cuisines type'>

# %%
expensive_cusinine['total_avgCost']
# Out:
# 1516    200450.0
# 1455    195900.0
# 1977     88470.0
# 1109     68300.0
# 2050     48080.0
# 431      43250.0
# 213      40260.0
# 1011     38950.0
# 1733     36850.0
# 307      36660.0
# Name: total_avgCost, dtype: float64

# %% [markdown]
#  #  North Indian and Chines is most popular cuisine followed by North Indian and South indian

# %% [markdown]
#  # 4 .Are higher-rated restaurants more expensive?

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# ...

# %%
cost_rating =df.groupby(["local address"])[["rate (out of 5)" , "avg cost (two people)"]].mean().reset_index().sort_values(by="avg cost (two people)" , ascending=False).head(10)

# %%
cost_rating
# Out:
#        local address  rate (out of 5)  avg cost (two people)
# 72       Sankey Road         4.045455            2886.363636
# 49      Lavelle Road         4.063158            1548.648649
# 64  Race Course Road         3.860714            1373.214286
# 50           MG Road         3.795238            1340.476190
# 67    Residency Road         3.792308            1205.769231
# 27     Infantry Road         3.772727            1086.363636
# 48     Langford Town         3.900000            1000.000000
# 68     Richmond Road         3.776667             957.500000
# 74     Seshadripuram         3.707692             905.128205
# 78    St. Marks Road         3.990476             897.619048

# %%
cost_rating['avg cost (two people)'] =np.ceil(cost_rating['avg cost (two people)'])
cost_rating['avg cost (two people)'] = cost_rating['avg cost (two people)'].astype(int)

cost_rating
# Out:
#        local address  rate (out of 5)  avg cost (two people)
# 72       Sankey Road         4.045455                   2887
# 49      Lavelle Road         4.063158                   1549
# 64  Race Course Road         3.860714                   1374
# 50           MG Road         3.795238                   1341
# 67    Residency Road         3.792308                   1206
# 27     Infantry Road         3.772727                   1087
# 48     Langford Town         3.900000                   1000
# 68     Richmond Road         3.776667                    958
# 74     Seshadripuram         3.707692                    906
# 78    St. Marks Road         3.990476                    898

# %%
#ploating data 

cost_rating.plot.line(y="rate (out of 5)" , x="avg cost (two people)" , marker="o")
# Out:
# <Axes: xlabel='avg cost (two people)'>

# %% [markdown]
# # Yes the Most rated restrount has more exepensive comared to low rated restrounts

# %% [markdown]
# # insights ------- 4

# %% [raw]
#  1. By overall data there is high density between 0 to 1000¶
#
#  2. Sankey Road is high average cost for two people with 2886.36 followed by Lavelle Road and Race Course Road with 1548 and       1373 respectively
#
#  3. the average cost for two peole is 230 in lowest average cost restrount
#
#  4. there is density starts from 250 and highly densed in 350 in low average cost city streets
#
#  5.Data shows that Nagarbavi has overall less average cost for two people of 250 followed by North Benglore and Peenya with        291 and 300 respectfull
#
#  6. data is highly dense between 50000 and 100000
#
#  7 . North Indian and Chines is most popular cuisine followed by North Indian and South indian

# %% [markdown]
#  # 5 Operational Analysis

# %% [markdown]
# # 1 How many restaurants offer online delivery?

# %%
online_offers =df[df['online_order']=="Yes"]
order_online_count = online_offers['online_order'].count()

# %%
order_online_count
# Out:
# 3727

# %% [markdown]
# # There are 3727 restrount which offers online order and remaining does not allow online order placement

# %% [markdown]
# # 2 . What percentage of restaurants offer table booking?

# %%
tabel_offers =df[df['table booking']=="Yes"]
count_tabel_offers = tabel_offers["table booking"].count()
total_hotels=df['table booking'].count()

percentage = (count_tabel_offers / total_hotels)*100
np.round(percentage , 2)
# Out:
# 10.47

# %% [markdown]
# # Only 10.47 percentage of restrount offers the online order plcement

# %% [markdown]
# # 3 . What are the top restaurant type on Zomato?

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# ...

# %%
#group based on most number of restrount types 

type_restrount=df.groupby(["restaurant type"])["area"].count().reset_index().sort_values(by="area" , ascending=False).head(10)

# %%
# type restrount 

type_restrount.plot.line(x="restaurant type" , y="area" , marker="o")
# Out:
# <Axes: xlabel='restaurant type'>

# %%
import matplotlib.pyplot as plt

counts = type_restrount['area']

# Assuming type_restrount is your DataFrame containing the data
bar =plt.barh(y=type_restrount['restaurant type'], width=type_restrount['area'])
plt.bar_label(bar , counts , label_type="edge")
plt.xlim(0,3500)
plt.xlabel('Restaurant Type')
plt.ylabel('Area')
plt.title('Bar Graph of Restaurant Type vs. Area')

plt.show()

# %% [markdown]
# # quick bites types of restrounts  are the most with 2840 followed by casual Dining and cefe with 1634 and 403 respectfully

# %% [markdown]
# # insights 5

# %% [raw]
# 1 There are 3727 restrount which offers online order and remaining does not allow online order placement
#
# 2. Only 10.47 percentage of restrount offers the online order plcement
#
# 3. quick bites types of restrounts are the most with 2840 followed by casual Dining and
#    cefe with 1634 and 403 respectfully

# %% [markdown]
# # Customer Preference Analysis --- 6

# %% [markdown]
# # 1. What is the most preferred cuisine in a specific city?

# %%
cuisines_cities =df.groupby(["area" , "cuisines type"])["restaurant name"].count().reset_index().sort_values(by="restaurant name" , ascending=False).head(10)

# %%
cuisines_cities.rename(columns={"restaurant name" : "count"} , inplace=True)

# %%
cuisines_cities
# Out:
#                                 area          cuisines type  count
# 1653  Byresandra,Tavarekere,Madiwala           North Indian     48
# 156                     Banashankari           South Indian     48
# 1259                     Brookefield           North Indian     47
# 1666  Byresandra,Tavarekere,Madiwala  North Indian, Chinese     46
# 386                Bannerghatta Road  North Indian, Chinese     39
# 736                        Bellandur           North Indian     39
# 3618                    Malleshwaram           South Indian     38
# 2516                     Indiranagar           North Indian     37
# 1270                     Brookefield  North Indian, Chinese     37
# 375                Bannerghatta Road           North Indian     34

# %%
plt.barh(y=cuisines_cities['area'] , width=cuisines_cities['count'])
plt.ylabel("city streets ")
plt.xlabel("number of restrounts")
plt.show()

# %%
# using subplots 
plt.subplot(2,2,1)
plt.barh(y=cuisines_cities['area'] , width=cuisines_cities['count'] )
plt.title("counts of cuisine in diffrent areas ")
plt.xlim(0,80)
plt.xlabel("number of hotels")
plt.ylabel("city streets ")
plt.show()


#using second subplot 


plt.subplot(2,2,1)
plt.barh(y=cuisines_cities['cuisines type'] , width=cuisines_cities['count'])
plt.xlim(0,85)
plt.xlabel(" number of hotels ")
plt.ylabel("cuisine types")
plt.show()

# %% [markdown]
#  # basvanaGudi  and Banashankari with 48 cuisines with NorthIndian and South Indian Respectfully followed by BrokeFeild with 47 northIndian

# %% [markdown]
# # 2. What are the top 10 most reviewed dishes?

# %%
df.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0 restaurant name restaurant type  rate (out of 5)  \
# 0             0           0    #FeelTheROLL     Quick Bites              3.4
# 1             1           1      #L-81 Cafe     Quick Bites              3.9
# 2             2           2         #refuel            Cafe              3.7
#
#    num of ratings  avg cost (two people) online_order table booking  \
# 0               7                  200.0           No            No
# 1              48                  400.0          Yes            No
# 2              37                  400.0          Yes            No
#
#           cuisines type                            area      local address
# 0             Fast Food                       Bellandur          Bellandur
# 1  Fast Food, Beverages  Byresandra,Tavarekere,Madiwala                HSR
# 2       Cafe, Beverages               Bannerghatta Road  Bannerghatta Road

# %%
cuisine_ratings =df.groupby(["cuisines type"])["rate (out of 5)"].max().reset_index().head(10)

# %%
cuisine_ratings
# Out:
#                                        cuisines type  rate (out of 5)
# 0                                    African, Burger              4.5
# 1                                           American              4.0
# 2  American, Asian, Continental, North Indian, So...              4.1
# 3            American, Asian, European, North Indian              4.3
# 4                                      American, BBQ              4.5
# 5                        American, Burger, Fast Food              4.2
# 6                   American, Burger, Italian, Steak              3.9
# 7                   American, Burger, Momos, Bengali              3.5
# 8         American, Cafe, Chinese, Italian, Desserts              2.8
# 9                        American, Cafe, Continental              4.4

# %%
# barploats 

sns.barplot(data=cuisine_ratings ,y="cuisines type" , x="rate (out of 5)" )
# Out:
# <Axes: xlabel='rate (out of 5)', ylabel='cuisines type'>

# %%
count_values = cuisine_ratings['rate (out of 5)']
bars =plt.barh(y=cuisine_ratings['cuisines type'] , width=cuisine_ratings['rate (out of 5)'])
plt.bar_label(bars, count_values ,padding=2)
plt.xlim(0,5)
plt.show()

# %% [markdown]
# # African Burger and  4.5 American BBQ with 4.5 rating where American cafe with 4.4 ratings

# %% [markdown]
# # insights --- 6

# %% [raw]
#  1. African Burger and 4.5 American BBQ with 4.5 rating where American cafe with 4.4 ratings
#
#  2. basvanaGudi and Banashankari with 48 cuisines with NorthIndian and South Indian Respectfully followed by BrokeFeild with       47 northIndian cuisines

# %% [markdown]
# # Final Insights (conclusion)

# %% [raw]
# # 1 General Analysis
#
# 1    . there are 6984 hotels or restrounts are listed in zomato
#
# 2  . Fast Food' 'Fast Food, Beverages' 'Cafe, Beverages' ...
#      'Italian, Mexican, Mediterranean  . are popular cuisines
#
# 3 .  popular cuisine is NORTH INDIAN ,CHINESE with 417 ratings followed by north indian cuisine 413
#
# 4   . moste rated restrounte type is Bar and pub with 4.6 followed by 4.4 Microbrewery, Pub
#
# 5  . their are 3721 hotels which accept online orders and 3263 hotels which accept which did not accept
#
#
# # 2 Based on location  data ananlysis
#
#
# 1. whitefield has most number of hotels with 457 followed by BTM 442
#
#  2. Peenya , NagarBhavi , Langford Town , kengeri have 1 hotels respectively followed by west benglore with 2 hotels
#
#  3. Lavelle Road have most has highest average restrount rating  4.05 with Sankey Road 4.04 and
#
#  4. whitefeild has most number of vierity of cuisine followed by BTM
#
#  5. whitefeild has most number of restrount  (459) followed by BTM (458) and Electronic city (404)
#
#  6. Sankey Road  has highest average cost of people about 2886 followed by Lavelle Road 1548 and Race Course Road 1373
#
#  7. Nagar Bhavi has low average(250) cost for two people followed by North BEnglore and Peenya
#
#  8.their more number of restrounts whose average cost for 2 two pople is in between 250 to 1000
#
#
#  # 3. Reviews Analysis
#
#
# 1 . there are 89.529 restrount which does not offer tabel booking service and only 10.471 percentage of
#       restrount offer tabel booking servivce
#
#
# 2 . Lavelle road street has highest rated with 4.063 followed by Sankey Road with 4.045
#
#
# 3. Vartur main road whitefield has lowested rated street with 2.98 followed by north
#    benglore and south benglore with 3.05 and    3.15
#
#
# #  4 . Cost analysis
#
#  1. By overall data there is high density between 0 to 1000¶
#
#  2. Sankey Road is high average cost for two people with 2886.36 followed by Lavelle Road and Race Course Road with 1548 and       1373 respectively
#
#  3. the average cost for two peole is 230 in lowest average cost restrount
#
#  4. there is density starts from 250 and highly densed in 350 in low average cost city streets
#
#  5.Data shows that Nagarbavi has overall less average cost for two people of 250 followed by North Benglore and Peenya with        291 and 300 respectfull
#
#  6. data is highly dense between 50000 and 100000
#
#  7 . North Indian and Chines is most popular cuisine followed by North Indian and South indian
#
#
# #operational analysis
#
# 1 There are 3727 restrount which offers online order and remaining does not allow online order placement
#
# 2. Only 10.47 percentage of restrount offers the online order plcement
#
# 3. quick bites types of restrounts are the most with 2840 followed by casual Dining and
#    cefe with 1634 and 403 respectfully
#
#
#
# # 6 custameers prefrence Analysis
#
#  1. African Burger and 4.5 American BBQ with 4.5 rating where American cafe with 4.4 ratings
#
#  2. basvanaGudi and Banashankari with 48 cuisines with NorthIndian and South Indian Respectfully followed by BrokeFeild with       47 northIndian cuisines
